# %% [markdown]
# # Bearing Failure Anomaly Detection

# %% [markdown]
# ### Blog: https://towardsdatascience.com/lstm-autoencoder-for-anomaly-detection-e1f4f2ee7ccf
# ### Github: https://github.com/BLarzalere/LSTM-Autoencoder-for-Anomaly-Detection

# %% [markdown]
# In this workbook, we use an autoencoder neural network to identify vibrational anomalies from sensor readings in a set of bearings. The goal is to be able to predict future bearing failures before they happen. The vibrational sensor readings are from the NASA Acoustics and Vibration Database. Each data set consists of individual files that are 1-second vibration signal snapshots recorded at 10 minute intervals. Each file contains 20,480 sensor data points that were obtained by reading the bearing sensors at a sampling rate of 20 kHz.
#
# This autoencoder neural network model is created using Long Short-Term Memory (LSTM) recurrent neural network (RNN) cells within the Keras / TensorFlow framework.

# %%
# !pip install scikit-learn joblib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/pietro/.local/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: joblib in /home/pietro/.local/lib/python3.11/site-packages (1.4.2)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy>=1.19.5 in /home/pietro/.local/lib/python3.11/site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/pietro/.local/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/pietro/.local/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pandas>=1.2 in /home/pietro/.local/lib/python3.11/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/pietro/.local/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pietro/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/pietro/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pietro/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pietro/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/pietro/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /home/pietro/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/pietro/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pietro/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pietro/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/pietro/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/pietro/.local/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# import libraries
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import joblib
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline
from glob import glob



from numpy.random import seed
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tensorflow.keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector, Lambda, Reshape, Concatenate, Conv1D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

# %%
# set random seed
seed(10)
tf.random.set_seed(10)

# %% [markdown]
# # Data loading and pre-processing
# An assumption is that mechanical degradation in the bearings occurs gradually over time; therefore, we use one datapoint every 10 minutes in the analysis. Each 10 minute datapoint is aggregated by using the mean absolute value of the vibration recordings over the 20,480 datapoints in each file. We then merge together everything in a single dataframe.

# %%
folder_path = "./MyData/"

# Get a list of all text files in the folder
file_list = glob(os.path.join(folder_path, "*.txt"))

# Create empty lists to store data from each file
all_gyro_data = []
all_acceleration_data = []
all_linear_acceleration_data = []

# Iterate through each file in the folder
for file_path in file_list:
    # Read the file into a DataFrame
    df = pd.read_csv(file_path, header=None)

    # Rename columns for clarity
    df.columns = ['Category', 'Timestamp', 'X', 'Y', 'Z']

    # Convert 'Timestamp' to datetime and set as the index
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
    df.set_index('Timestamp', inplace=True)

    # Split data based on the 'Category' column and drop the 'Category' column
    gyro_data = df[df['Category'] == 0].drop(columns=['Category'])
    acceleration_data = df[df['Category'] == 1].drop(columns=['Category'])
    linear_acceleration_data = df[df['Category'] == 2].drop(columns=['Category'])

    # Append the data to the corresponding lists
    all_gyro_data.append(gyro_data)
    all_acceleration_data.append(acceleration_data)
    all_linear_acceleration_data.append(linear_acceleration_data)

# %%
all_gyro_data[1]
# Out:
#                                  X    Y    Z
# Timestamp
# 2024-12-09 16:33:05.695379019   33  231  224
# 2024-12-09 16:33:05.697213888   76 -210  -11
# 2024-12-09 16:33:05.755386353  477  -63  245
# 2024-12-09 16:33:05.867717028    5 -258    0
# 2024-12-09 16:33:06.024510622  385  -61   -3
# ...                            ...  ...  ...
# 2024-12-09 16:38:23.418895006  283 -429  179
# 2024-12-09 16:38:23.442604303 -394  -64 -134
# 2024-12-09 16:38:23.475518227  155 -120   92
# 2024-12-09 16:38:23.508924723   22 -641  281
# 2024-12-09 16:38:23.531944513  379   28  174
#
# [10458 rows x 3 columns]

# %%
# transform data file index to datetime and sort in chronological order
merged_data.index = pd.to_datetime(merged_data.index, format='%Y.%m.%d.%H.%M.%S')
merged_data = merged_data.sort_index()
merged_data.to_csv('Averaged_BearingTest_Dataset.csv')
print("Dataset shape:", merged_data.shape)
merged_data.head()
# Out:
# Dataset shape: (982, 4)
#                      Bearing 1  Bearing 2  Bearing 3  Bearing 4
# 2004-02-12 10:52:39   0.060236   0.074227   0.083926   0.044443
# 2004-02-12 11:02:39   0.061455   0.073844   0.084457   0.045081
# 2004-02-12 11:12:39   0.061361   0.075609   0.082837   0.045118
# 2004-02-12 11:22:39   0.061665   0.073279   0.084879   0.044172
# 2004-02-12 11:32:39   0.061944   0.074593   0.082626   0.044659

# %% [markdown]
# # Define train/test data
# Before setting up the models, we need to define train/test data. To do this, we perform a simple split where we train on the first part of the dataset (which should represent normal operating conditions) and test on the remaining parts of the dataset leading up to the bearing failure.

# %%
train = merged_data['2004-02-12 10:52:39': '2004-02-15 12:52:39']
test = merged_data['2004-02-15 12:52:39':]
print("Training dataset shape:", train.shape)
print("Test dataset shape:", test.shape)
# Out:
# Training dataset shape: (445, 4)
# Test dataset shape: (538, 4)

# %%
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train['Bearing 1'], label='Bearing 1', color='blue', animated = True, linewidth=1)
ax.plot(train['Bearing 2'], label='Bearing 2', color='red', animated = True, linewidth=1)
ax.plot(train['Bearing 3'], label='Bearing 3', color='green', animated = True, linewidth=1)
ax.plot(train['Bearing 4'], label='Bearing 4', color='black', animated = True, linewidth=1)
plt.legend(loc='lower left')
ax.set_title('Bearing Sensor Training Data', fontsize=16)
plt.show()

# %% [markdown]
# Let’s get a different perspective of the data by transforming the signal from the time domain to the frequency domain using a discrete Fourier transform.

# %%
# transforming data from the time domain to the frequency domain using fast Fourier transform
all_gyro_data_fft=[]
for train in all_gyro_data:
    all_gyro_data_fft.append(np.fft.fft(train))

# %%
# frequencies of the healthy sensor signal
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(all_gyro_data_fft[0][:,0].real, label='Bearing 1', color='blue', animated = True, linewidth=1)
ax.plot(all_gyro_data_fft[0][:,1].real, label='Bearing 2', color='red', animated = True, linewidth=1)
ax.plot(all_gyro_data_fft[0][:,2].real, label='Bearing 3', color='green', animated = True, linewidth=1)
ax.plot(all_gyro_data_fft[0][:,3].real, label='Bearing 4', color='black', animated = True, linewidth=1)
plt.legend(loc='lower left')
ax.set_title('Bearing Sensor Training Frequency Data', fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 6
#       4 ax.plot(all_gyro_data_fft[0][:,1].real, label='Bearing 2', color='red', animated = True, linewidth=1)
#       5 ax.plot(all_gyro_data_fft[0][:,2].real, label='Bearing 3', color='green', animated = True, linewidth=1)
# ----> 6 ax.plot(all_gyro_data_fft[0][:,3].real, label='Bearing 4', color='black', animated = True, linewidth=1)
#       7 plt.legend(loc='lower left')
#       8 ax.set_title('Bearing Sensor Training Frequency Data', fontsize=16)
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
# frequencies of the healthy sensor signal
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(all_gyro_data_fft[1][:,0].real, label='Bearing 1', color='blue', animated = True, linewidth=1)
ax.plot(all_gyro_data_fft[1][:,1].real, label='Bearing 2', color='red', animated = True, linewidth=1)
ax.plot(all_gyro_data_fft[1][:,2].real, label='Bearing 3', color='green', animated = True, linewidth=1)
plt.legend(loc='lower left')
ax.set_title('Bearing Sensor Training Frequency Data', fontsize=16)
plt.show()
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(all_acceleration_data [1]["X"], label='Bearing 1', color='blue', animated = True, linewidth=1)
ax.plot(all_acceleration_data [1]["Y"], label='Bearing 2', color='red', animated = True, linewidth=1)
ax.plot(all_acceleration_data [1]["Z"], label='Bearing 3', color='green', animated = True, linewidth=1)
plt.legend(loc='lower left')
ax.set_title('Bearing Sensor Training Data', fontsize=16)
plt.show()

# %%
# normalize the data
X_train=[]
for train in  all_gyro_data:
    scaler = MinMaxScaler()
    X_train.append(scaler.fit_transform(train))
    scaler_filename = "scaler_data"
    joblib.dump(scaler, scaler_filename)

# %%
# reshape inputs for LSTM [samples, timesteps, features]
X_train1=[]
for X_train_ in X_train:  
    X_train_ = X_train_.reshape(X_train_.shape[0], 1, X_train_.shape[1])
    print("Training data shape:", X_train_.shape)
    X_train1.append(X_train_)
X_train=X_train1
# Out:
# Training data shape: (18189, 1, 3)
# Training data shape: (10458, 1, 3)
# Training data shape: (11490, 1, 3)
# Training data shape: (9281, 1, 3)
# Training data shape: (2716, 1, 3)
# Training data shape: (10094, 1, 3)

# %%
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    reference_inputs = Input(shape=(None, X.shape[2]))

    # Encoder for main input
    L1 = LSTM(16, activation='relu', return_sequences=True)(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)

    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    reconstruction_output = TimeDistributed(Dense(X.shape[2]))(L5)

    # Encoder for reference input
    R1 = LSTM(16, activation='relu', return_sequences=False)(reference_inputs)
    R2 = RepeatVector(X.shape[1])(R1)

    # Combine outputs
    combined = Concatenate()([reconstruction_output, R2])
    anomaly_score = Dense(1, activation='sigmoid', name='anomaly_score')(combined)

    # Final model with both reconstruction and anomaly outputs
    model = Model(inputs=[inputs, reference_inputs], outputs=[reconstruction_output, anomaly_score])
    return model

# %%
def autoencoder_model2(X,Y):
    # Input for the main data (original input)
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    
    # Apply 1x1 convolution to reduce feature dimensions
    conv1 = Conv1D(filters=8, kernel_size=1, activation='relu')(inputs)  # Reducing features to 8
    
    # Input for the reference data (guidance input)
    reference_inputs = Input(shape=(Y.shape[1], Y.shape[2]))
    reference_conv1 = Conv1D(filters=8, kernel_size=1, activation='relu')(reference_inputs)

    # Encoder path for the main input
    L1 = LSTM(16, activation='relu', return_sequences=True)(conv1)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    
    # RepeatVector to match the sequence length for decoding
    L3 = RepeatVector(X.shape[1])(L2)
    
    # Decoder path for reconstruction
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    reconstruction_output = TimeDistributed(Dense(X.shape[2]), name='reconstruction_output')(L5)
    
    # Encoder path for the reference input
    R1 = LSTM(16, activation='relu', return_sequences=False)(reference_conv1)  # Encodes to 16 values
    R2 = RepeatVector(X.shape[1])(R1)  # Repeat to match the length of the original input
    
    # Combine the outputs from the main input and the reference input
    combined = Concatenate()([reconstruction_output, R2])
    
    # Anomaly score prediction
    anomaly_score = Dense(1, activation='sigmoid', name='anomaly_score')(combined)

    # Define the model with two inputs and two outputs
    model = Model(inputs=[inputs, reference_inputs], outputs=[reconstruction_output, anomaly_score])
    model.compile(optimizer=Adam(learning_rate=0.001), 
                  loss={'reconstruction_output': 'mse', 'anomaly_score': 'binary_crossentropy'},
                  loss_weights={'reconstruction_output': 1.0, 'anomaly_score': 0.5})
    return model

# %%
model2.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12      │ (None, 18189, 1)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 18189, 8)  │         16 │ input_layer_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_22 (LSTM)      │ (None, 18189, 16) │      1,600 │ conv1d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_23 (LSTM)      │ (None, 4)         │        336 │ lstm_22[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_8     │ (None, 18189, 4)  │          0 │ lstm_23[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_13      │ (None, 18189, 1)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_24 (LSTM)      │ (None, 18189, 4)  │        144 │ repeat_vector_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 18189, 8)  │         16 │ input_layer_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_25 (LSTM)      │ (None, 18189, 16) │      1,344 │ lstm_24[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_26 (LSTM)      │ (None, 16)        │      1,600 │ conv1d_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reconstruction_out… │ (None, 18189, 1)  │         17 │ lstm_25[0][0]     │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_9     │ (None, 18189, 16) │          0 │ lstm_26[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 18189, 17) │          0 │ reconstruction_o… │
# │ (Concatenate)       │                   │            │ repeat_vector_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ anomaly_score       │ (None, 18189, 1)  │         18 │ concatenate_4[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,091 (19.89 KB)
#  Trainable params: 5,091 (19.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
max_len = max([len(seq) for seq in X_train])
X_train_padded = pad_sequences(X_train, maxlen=max_len, dtype='float32', padding='post', truncating='post')
X_train_padded = np.array([np.expand_dims(seq, axis=0) for seq in X_train_padded])  # Add batch dimension

model2 = autoencoder_model2(X_train_padded[0], X_train_padded[0])

# %%
nb_epochs = 100
batch_size = 1
train_pairs = [
    (i, j) for i in range(len(X_train)) for j in range(len(X_train)) 
]
for i, j in train_pairs:
    # Truncate the reference sequence to match the main sequence length
    main_input = X_train_padded[0][i]  # Shape: (sequence_length, num_features)
    reference_input = X_train_padded[0][j][:main_input.shape[0]]  # Truncate reference input
    
    # Reshape inputs to match model's input expectations
    main_input = np.expand_dims(main_input, axis=-1)  # Shape: (sequence_length, num_features=1)
    reference_input = np.expand_dims(reference_input, axis=-1)  # Shape: (sequence_length, num_features=1)
    
    main_input = np.expand_dims(main_input, axis=0)  # Add batch dimension: (1, sequence_length, num_features=1)
    reference_input = np.expand_dims(reference_input, axis=0)  # Add batch dimension: (1, sequence_length, num_features=1)
    
    x_input = [main_input, reference_input]  # List of inputs for the model
    
    # Prepare outputs
    y_reconstruction = np.expand_dims(main_input[0], axis=0)  # Add batch dimension
    y_anomaly = np.array([0 if i == j else 1])  # Binary flag for anomaly
    
    y_output = {
        'reconstruction_output': y_reconstruction,  # Target reconstruction
        'anomaly_score': y_anomaly  # Anomaly label
    }
    
    # Train the model
    history = model2.fit(
        x=x_input,
        y=y_output,
        epochs=nb_epochs,
        batch_size=1,  # Single pair training
        verbose=0
    )
# Out:
# /home/pietro/.local/lib/python3.11/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_80', 'keras_tensor_82']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 30
#      24 y_output = {
#      25     'reconstruction_output': y_reconstruction,  # Target reconstruction
#      26     'anomaly_score': y_anomaly  # Anomaly label
#      27 }
#      29 # Train the model
# ---> 30 history = model2.fit(
#      31     x=x_input,
#      32     y=y_output,
#      33     epochs=nb_epochs,
#      34     batch_size=1,  # Single pair training
#      35     verbose=0
#      36 )
#
# File ~/.local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.local/lib/python3.11/site-packages/keras/src/models/functional.py:264, in Functional._adjust_input_rank(self, flat_inputs)
#     262             adjusted.append(ops.expand_dims(x, axis=-1))
#     263             continue
# --> 264     raise ValueError(
#     265         f"Invalid input shape for input {x}. Expected shape "
#     266         f"{ref_shape}, but input has incompatible shape {x.shape}"
#     267     )
#     268 # Add back metadata.
#     269 for i in range(len(flat_inputs)):
#
# ValueError: Exception encountered when calling Functional.call().
#
# Invalid input shape for input Tensor("data:0", shape=(1, 18189, 1, 3, 1), dtype=float32). Expected shape (None, 18189, 1), but input has incompatible shape (1, 18189, 1, 3, 1)
#
# Arguments received by Functional.call():
#   • inputs=('tf.Tensor(shape=(1, 18189, 1, 3, 1), dtype=float32)', 'tf.Tensor(shape=(1, 18189, 1, 3, 1), dtype=float32)')
#   • training=True
#   • mask=('None', 'None')

# %%
X_train=np.array(X_train, dtype=object)

# %%
X_train[0].shape
# Out:
# (18189, 1, 3)

# %%
model_path = "./model.keras"

model = load_model(model_path)

model.summary()
# Out:
# 2024-12-11 11:12:41.825716: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 1, 3)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_20 (LSTM)      │ (None, 1, 16)     │      1,280 │ input_layer_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_21 (LSTM)      │ (None, 4)         │        336 │ lstm_20[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_8     │ (None, 1, 4)      │          0 │ lstm_21[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_22 (LSTM)      │ (None, 1, 4)      │        144 │ repeat_vector_8[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_9       │ (None, None, 3)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_23 (LSTM)      │ (None, 1, 16)     │      1,344 │ lstm_22[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_24 (LSTM)      │ (None, 16)        │      1,280 │ input_layer_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_4  │ (None, 1, 3)      │         51 │ lstm_23[0][0]     │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_9     │ (None, 1, 16)     │          0 │ lstm_24[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 1, 19)     │          0 │ time_distributed… │
# │ (Concatenate)       │                   │            │ repeat_vector_9[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1, 3)      │         60 │ concatenate_3[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 13,487 (52.69 KB)
#  Trainable params: 4,495 (17.56 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 8,992 (35.13 KB)

# %%
model_path = "./model.keras"

model.save(model_path)

# %%
# create the autoencoder model
model = autoencoder_model(X_train[0])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_14      │ (None, 1, 3)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_27 (LSTM)      │ (None, 1, 16)     │      1,280 │ input_layer_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_28 (LSTM)      │ (None, 4)         │        336 │ lstm_27[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_10    │ (None, 1, 4)      │          0 │ lstm_28[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_29 (LSTM)      │ (None, 1, 4)      │        144 │ repeat_vector_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_15      │ (None, None, 3)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_30 (LSTM)      │ (None, 1, 16)     │      1,344 │ lstm_29[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_31 (LSTM)      │ (None, 16)        │      1,280 │ input_layer_15[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_3  │ (None, 1, 3)      │         51 │ lstm_30[0][0]     │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_11    │ (None, 1, 16)     │          0 │ lstm_31[0][0]     │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 1, 19)     │          0 │ time_distributed… │
# │ (Concatenate)       │                   │            │ repeat_vector_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1, 3)      │         60 │ concatenate_5[0]… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,495 (17.56 KB)
#  Trainable params: 4,495 (17.56 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit the model to the data
nb_epochs = 100
batch_size = 10
input_data=[]
output_data=[]
for train_j in range(len(X_train)):
    for train_i in range(len(X_train)):
        if len(X_train[train_i])<=len(X_train[train_j]):
            if train_j != train_i:
                # Create a pair of training data and the corresponding output
                x_input = (X_train[train_i],X_train[train_j][0:len(X_train[train_i])])
                y_output = X_train[train_i] * 10  # Adjust this according to your target needs
                input_data.append(x_input)
                output_data.append(y_output)
                # Train the model on this data pair
                #history = model.fit(x_input, y_output, epochs=nb_epochs, batch_size=batch_size, validation_split=0.05).history
            else:
                # This block might need adjustment, as it uses the same data point
                x_input = (X_train[train_i], X_train[train_i])
                y_output = X_train[train_i]  # Ensure this is the desired target
                input_data.append(x_input)
                output_data.append(y_output)
                # Train the model on this data pair
                #history = model.fit(x_input, y_output, epochs=nb_epochs, batch_size=batch_size, validation_split=0.05).history
history = model.fit(x_input, y_output, epochs=nb_epochs, batch_size=batch_size, validation_split=0.05).history
# Out:
# Epoch 1/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 5.7063e-06 - val_loss: 3.1772e-06
# Epoch 2/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 4.5064e-06 - val_loss: 2.7512e-06
# Epoch 3/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3.5304e-06 - val_loss: 3.8154e-06
# Epoch 4/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.7497e-06 - val_loss: 3.1680e-06
# Epoch 5/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.0955e-06 - val_loss: 1.2710e-06
# Epoch 6/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.5400e-06 - val_loss: 6.4676e-07
# Epoch 7/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1703e-06 - val_loss: 4.9644e-07
# Epoch 8/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 8.9988e-07 - val_loss: 3.3184e-07
# Epoch 9/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 6.7362e-07 - val_loss: 4.3349e-07
# Epoch 10/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 5.5184e-07 - val_loss: 5.0967e-07
# Epoch 11/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 4.5359e-07 - val_loss: 5.1864e-07
# Epoch 12/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3.8648e-07 - val_loss: 2.5648e-07
# Epoch 13/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 3.1470e-07 - val_loss: 1.6491e-07
# Epoch 14/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.8582e-07 - val_loss: 2.5554e-07
# Epoch 15/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.8821e-07 - val_loss: 3.8847e-07
# Epoch 16/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.6915e-07 - val_loss: 3.7068e-07
# Epoch 17/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.3729e-07 - val_loss: 3.2096e-07
# Epoch 18/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 2.1354e-07 - val_loss: 2.7088e-07
# Epoch 19/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.9536e-07 - val_loss: 2.0573e-07
# Epoch 20/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.8312e-07 - val_loss: 1.6121e-07
# Epoch 21/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.8570e-07 - val_loss: 1.6748e-07
# Epoch 22/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.8321e-07 - val_loss: 2.0184e-07
# Epoch 23/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.8046e-07 - val_loss: 1.9534e-07
# Epoch 24/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.8017e-07 - val_loss: 1.2126e-07
# Epoch 25/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.8781e-07 - val_loss: 1.3095e-07
# Epoch 26/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.8730e-07 - val_loss: 1.3860e-07
# Epoch 27/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.6710e-07 - val_loss: 1.3110e-07
# Epoch 28/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.5118e-07 - val_loss: 1.4254e-07
# Epoch 29/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 1.5489e-07 - val_loss: 1.5193e-07
# Epoch 30/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.5376e-07 - val_loss: 1.6505e-07
# Epoch 31/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.5246e-07 - val_loss: 1.5862e-07
# Epoch 32/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.4588e-07 - val_loss: 1.6238e-07
# Epoch 33/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.4607e-07 - val_loss: 1.4833e-07
# Epoch 34/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.4056e-07 - val_loss: 1.3496e-07
# Epoch 35/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.3440e-07 - val_loss: 1.1316e-07
# Epoch 36/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.2791e-07 - val_loss: 9.8964e-08
# Epoch 37/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.2455e-07 - val_loss: 9.1186e-08
# Epoch 38/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.2110e-07 - val_loss: 8.2495e-08
# Epoch 39/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1889e-07 - val_loss: 7.7609e-08
# Epoch 40/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1893e-07 - val_loss: 7.5238e-08
# Epoch 41/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1856e-07 - val_loss: 7.3724e-08
# Epoch 42/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1735e-07 - val_loss: 7.5066e-08
# Epoch 43/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.1533e-07 - val_loss: 7.1711e-08
# Epoch 44/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1237e-07 - val_loss: 7.8579e-08
# Epoch 45/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1341e-07 - val_loss: 8.3148e-08
# Epoch 46/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1265e-07 - val_loss: 8.6466e-08
# Epoch 47/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1191e-07 - val_loss: 8.8232e-08
# Epoch 48/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1098e-07 - val_loss: 9.3060e-08
# Epoch 49/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.1081e-07 - val_loss: 1.0029e-07
# Epoch 50/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.0970e-07 - val_loss: 1.0619e-07
# Epoch 51/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.0859e-07 - val_loss: 1.0860e-07
# Epoch 52/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.0709e-07 - val_loss: 1.0860e-07
# Epoch 53/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.0516e-07 - val_loss: 1.0813e-07
# Epoch 54/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.0371e-07 - val_loss: 1.0860e-07
# Epoch 55/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.0221e-07 - val_loss: 1.0878e-07
# Epoch 56/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.0093e-07 - val_loss: 1.0944e-07
# Epoch 57/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 9.9762e-08 - val_loss: 1.1014e-07
# Epoch 58/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 9.8498e-08 - val_loss: 1.1549e-07
# Epoch 59/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 9.6323e-08 - val_loss: 1.1455e-07
# Epoch 60/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 9.4854e-08 - val_loss: 1.1000e-07
# Epoch 61/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 9.4208e-08 - val_loss: 1.0316e-07
# Epoch 62/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 9.4429e-08 - val_loss: 9.7439e-08
# Epoch 63/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 9.4048e-08 - val_loss: 1.0185e-07
# Epoch 64/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 9.2507e-08 - val_loss: 1.2776e-07
# Epoch 65/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 9.1227e-08 - val_loss: 1.2825e-07
# Epoch 66/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 9.0114e-08 - val_loss: 1.2376e-07
# Epoch 67/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 9.0197e-08 - val_loss: 1.1856e-07
# Epoch 68/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 8.9991e-08 - val_loss: 1.1377e-07
# Epoch 69/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 8.9561e-08 - val_loss: 1.0931e-07
# Epoch 70/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 8.9217e-08 - val_loss: 1.0587e-07
# Epoch 71/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.8636e-08 - val_loss: 1.0210e-07
# Epoch 72/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 8.8125e-08 - val_loss: 9.8939e-08
# Epoch 73/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.7663e-08 - val_loss: 9.5735e-08
# Epoch 74/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.7238e-08 - val_loss: 9.2633e-08
# Epoch 75/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 8.6828e-08 - val_loss: 8.9562e-08
# Epoch 76/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.6472e-08 - val_loss: 8.6746e-08
# Epoch 77/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.6043e-08 - val_loss: 8.4046e-08
# Epoch 78/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.5629e-08 - val_loss: 8.1572e-08
# Epoch 79/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.5140e-08 - val_loss: 7.9108e-08
# Epoch 80/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.4665e-08 - val_loss: 7.6774e-08
# Epoch 81/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.4122e-08 - val_loss: 7.4791e-08
# Epoch 82/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.3581e-08 - val_loss: 7.2837e-08
# Epoch 83/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 8.3152e-08 - val_loss: 7.1096e-08
# Epoch 84/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.2628e-08 - val_loss: 6.9418e-08
# Epoch 85/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.2180e-08 - val_loss: 6.7933e-08
# Epoch 86/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.1755e-08 - val_loss: 6.6806e-08
# Epoch 87/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 8.1420e-08 - val_loss: 6.5433e-08
# Epoch 88/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 8.1064e-08 - val_loss: 6.4308e-08
# Epoch 89/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 8.0702e-08 - val_loss: 6.3203e-08
# Epoch 90/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.0354e-08 - val_loss: 6.2268e-08
# Epoch 91/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.0048e-08 - val_loss: 6.1379e-08
# Epoch 92/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 7.9765e-08 - val_loss: 6.0442e-08
# Epoch 93/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 7.9447e-08 - val_loss: 5.9729e-08
# Epoch 94/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 7.9162e-08 - val_loss: 5.8842e-08
# Epoch 95/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 7.8952e-08 - val_loss: 5.8184e-08
# Epoch 96/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 7.8713e-08 - val_loss: 5.7501e-08
# Epoch 97/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 7.8444e-08 - val_loss: 5.6721e-08
# Epoch 98/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 7.8205e-08 - val_loss: 5.6171e-08
# Epoch 99/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 7.7986e-08 - val_loss: 5.5707e-08
# Epoch 100/100
# 959/959 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 7.7846e-08 - val_loss: 5.5044e-08

# %%
def test_model(model, X_test, nb_samples=10):
    results = []  # To store inputs and outputs
    sample_count = 0  # To track how many samples we've processed

    for test_i in range(len(X_test)):
        for test_j in range(len(X_test)):
            if len(X_test[test_i]) <= len(X_test[test_j]):
                if test_j != test_i:
                    # Create a pair of test data
                    x_input = (X_test[test_i], X_test[test_j][0:len(X_test[test_i])])
                else:
                    # Use the same data point as input
                    x_input = (X_test[test_i], X_test[test_i])

                # Predict the output using the trained model
                y_pred = model.predict([x_input[0], x_input[1]])

                # Store the input and output in the results list
                results.append({
                    'input_1': x_input[0],
                    'input_2': x_input[1],
                    'output': y_pred,
                    'info':{
                        'source': str(test_i),
                        'reference':str(test_j)
                    }
                })

                # Increment the sample count and check if we reached the limit
                sample_count += 1
                if sample_count >= nb_samples:
                    return results

    return results

# %%
result=test_model(model, X_train)
# Out:
# 569/569 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 360/360 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
result[1]["info"]
# Out:
# {'source': '1', 'reference': '0'}

# %%
input_1 = result[1]["output"].squeeze()  # Flatten and get the last dimension (ignoring the 1)
print(input_1.shape)
# Create x-axis for plotting
x = np.arange(len(input_1))

plt.figure(figsize=(10, 5))
plt.plot(x, input_1[:, 0], label='Feature 1')
plt.plot(x, input_1[:, 1], label='Feature 2')
plt.plot(x, input_1[:, 2], label='Feature 3')
plt.xlabel('Index')
plt.ylabel('Values')
plt.title('Features 1, 2, and 3 vs Index')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# (10458, 3)

# %%
anomalies = {}
for res in result:
    input_1=res["input_1"].squeeze()
    input_2=res["input_2"].squeeze() 
    output=res["output"].squeeze() 
    info=res["info"]
    print(info)
    for i in range(len(input_1)):
        if abs(input_1[i][0]- output[i][0])>0.1:
            anomalies[str(info)]=anomalies.get(str(info), 0)+1
print(anomalies)
# Out:
# {'source': '0', 'reference': '0'}
# {'source': '1', 'reference': '0'}
# {'source': '1', 'reference': '1'}
# {'source': '1', 'reference': '2'}
# {'source': '2', 'reference': '0'}
# {'source': '2', 'reference': '2'}
# {'source': '3', 'reference': '0'}
# {'source': '3', 'reference': '1'}
# {'source': '3', 'reference': '2'}
# {'source': '3', 'reference': '3'}
# {"{'source': '1', 'reference': '0'}": 7228, "{'source': '1', 'reference': '2'}": 7512, "{'source': '2', 'reference': '0'}": 7873, "{'source': '3', 'reference': '0'}": 5804, "{'source': '3', 'reference': '1'}": 6200, "{'source': '3', 'reference': '2'}": 6295}

# %%
print(len(result))
# Out:
# 10

# %%
def representative_data_gen():
    for i in range(100):  # Adjust the range as needed
        input_data = X_train[i:i+1]  # Ensure this slices correctly
        #print(f"Yielding data shape: {input_data.shape}, dtype: {input_data.dtype}")
        yield [input_data.astype(np.float32)]

# %%
X_train[0]+10
# Out:
# array([[[10.80276134, 10.51677852, 10.4518647 ]],
#
#        [[10.52465483, 10.58964525, 10.84648742]],
#
#        [[10.22945431, 10.64813039, 10.65047702]],
#
#        ...,
#
#        [[10.70742932, 10.0105465 , 10.5329575 ]],
#
#        [[10.49375411, 10.44199425, 10.50823938]],
#
#        [[10.43458251, 10.56136146, 10.47181266]]])

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Lambda
# create the autoencoder model
#model = autoencoder_model2(X_train)
#model.compile(optimizer='adam', loss='mae')
#model.summary()
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.allow_custom_ops = True
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8  # Set input type to int8
converter.inference_output_type = tf.int8  #
converter.experimental_new_converter = True
converter.experimental_enable_resource_variables = True
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # TensorFlow Lite built-in operations
    tf.lite.OpsSet.SELECT_TF_OPS     # TensorFlow operations that are not natively supported
]
converter._experimental_lower_tensor_list_ops = False

tflite_model = converter.convert()
with open('./autoencoder_model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpd8zs8ue1/assets
# INFO:tensorflow:Assets written to: /tmp/tmpd8zs8ue1/assets
# Saved artifact at '/tmp/tmpd8zs8ue1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1, 4), dtype=tf.float32, name='keras_tensor_3')
# Output Type:
#   TensorSpec(shape=(None, 1, 4), dtype=tf.float32, name=None)
# Captures:
#   140003623771152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623771536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623770576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623773264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623773456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623772112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623773648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623776336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623775568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623776912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623778448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623776720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623779600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140003623779216: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/pietro/.local/lib/python3.11/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1733234076.027220  235600 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1733234076.027239  235600 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2024-12-03 14:54:36.027541: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpd8zs8ue1
# 2024-12-03 14:54:36.031194: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2024-12-03 14:54:36.031245: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpd8zs8ue1
# 2024-12-03 14:54:36.063010: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2024-12-03 14:54:36.173925: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpd8zs8ue1
# 2024-12-03 14:54:36.228783: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 201247 microseconds.
# 2024-12-03 14:54:36.459421: W tensorflow/compiler/mlir/lite/flatbuffer_export.cc:3825] TFLite interpreter needs to link Flex delegate in order to run the model since it contains the following Select TFop(s):
# Flex ops: FlexTensorListReserve, FlexTensorListSetItem, FlexTensorListStack
# Details:
# 	tf.TensorListReserve(tensor<2xi32>, tensor<i32>) -> (tensor<!tf_type.variant<tensor<?x16xf32>>>) : {device = ""}
# 	tf.TensorListReserve(tensor<2xi32>, tensor<i32>) -> (tensor<!tf_type.variant<tensor<?x4xf32>>>) : {device = ""}
# 	tf.TensorListSetItem(tensor<!tf_type.variant<tensor<?x16xf32>>>, tensor<i32>, tensor<?x16xf32>) -> (tensor<!tf_type.variant<tensor<?x16xf32>>>) : {device = "", resize_if_index_out_of_bounds = false}
# 	tf.TensorListSetItem(tensor<!tf_type.variant<tensor<?x4xf32>>>, tensor<i32>, tensor<?x4xf32>) -> (tensor<!tf_type.variant<tensor<?x4xf32>>>) : {device = "", resize_if_index_out_of_bounds = false}
# 	tf.TensorListStack(tensor<!tf_type.variant<tensor<?x16xf32>>>, tensor<2xi32>) -> (tensor<1x?x16xf32>) : {device = "", num_elements = 1 : i64}
# 	tf.TensorListStack(tensor<!tf_type.variant<tensor<?x4xf32>>>, tensor<2xi32>) -> (tensor<1x?x4xf32>) : {device = "", num_elements = 1 : i64}
# See instructions: https://www.tensorflow.org/lite/guide/ops_select
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Distribution of Loss Function
# By plotting the distribution of the calculated loss in the training set, one can use this to identify a suitable threshold value for identifying an anomaly. In doing this, one can make sure that this threshold is set above the “noise level” and that any flagged anomalies should be statistically significant above the background noise.

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=train.columns)
X_pred.index = train.index

scored = pd.DataFrame(index=train.index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
plt.xlim([0.0,.5])

# %% [markdown]
# From the above loss distribution, let's try a threshold value of 0.275 for flagging an anomaly. We can then calculate the loss in the test set to check when the output crosses the anomaly threshold.

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=test.columns)
X_pred.index = test.index

scored = pd.DataFrame(index=test.index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = 0.275
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test2)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=test.columns)
X_pred.index = test.index

scored = pd.DataFrame(index=test.index)
Xtest = X_test2.reshape(X_test2.shape[0], X_test2.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = 0.275
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored=pd.concat([scored_train, scored])

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=train.columns)
X_pred_train.index = train.index

scored_train = pd.DataFrame(index=train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = 0.275
scored_train['Anomaly'] = scored_train['Loss_mae'] > scored_train['Threshold']
scored = pd.concat([scored_train, scored])

# %% [markdown]
# Having calculated the loss distribution and the anomaly threshold, we can visualize the model output in the time leading up to the bearing failure.

# %%
# plot bearing failure time plot
scored.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])

# %% [markdown]
# This analysis approach is able to flag the upcoming bearing malfunction well in advance of the actual physical failure. It is important to define a suitable threshold value for flagging anomalies while avoiding too many false positives during normal operating conditions.

# %%
# save all model information, including weights, in h5 format
model.save("bearing-sensor-anomaly-detection.h5")
print("Model saved")
